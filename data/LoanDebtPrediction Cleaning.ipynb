# %% [markdown]
# # Datasets Cleaning

# %% [markdown]
# ## Groceries Dataset Cleaning

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Groceries.csv')
df.head()
# Out:
#    Unnamed: 0  pulses_1kg  flour_10kg  rice_5kg  oil_1ltr  soap  \
# 0           0         102         501       595       275    52
# 1           1         105         498       552       390    50
# 2           2         178         444       643       331    65
# 3           3         164         327       470       263    30
# 4           4          99         404       533       347    30
#
#    amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0         3331276             13              3                1  ...
# 1         6690555              9              2                1  ...
# 2         5039662             12              4                1  ...
# 3         6230007             13              3                0  ...
# 4         1615383             13              2                1  ...
#
#    no_of_units_sold_per_day_of_pulses  no_of_units_sold_per_day_of_flour  \
# 0                                   9                                 17
# 1                                  10                                  5
# 2                                   8                                 18
# 3                                   6                                 13
# 4                                   8                                 10
#
#    no_of_units_sold_per_day_of_rice  no_of_units_sold_per_day_of_oil  \
# 0                                11                                3
# 1                                 9                                8
# 2                                19                               10
# 3                                12                                5
# 4                                 8                                9
#
#    no_of_units_sold_per_day_of_soap  profit_percentage_last_year  \
# 0                                26                            1
# 1                                30                           21
# 2                                21                           34
# 3                                32                           11
# 4                                15                           32
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  4               1        0                       0
# 1                  4               1        0                       1
# 2                  7               1        1                       0
# 3                  3               0        0                       0
# 4                  8               0        0                       0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Grocery Commodities Revenue

# %%
pulses_revenue = []
for i in range(0, 1000):
    pulses_revenue.append((df['pulses_1kg'].loc[i])*(df['no_of_units_sold_per_day_of_pulses'].loc[i])*365)

# %%
flour_revenue = []
for i in range(0, 1000):
    flour_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_flour'].loc[i])*365)

# %%
rice_revenue = []
for i in range(0, 1000):
    rice_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_rice'].loc[i])*365)

# %%
oil_revenue = []
for i in range(0, 1000):
    oil_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_oil'].loc[i])*365)

# %%
soap_revenue = []
for i in range(0, 1000):
    soap_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_soap'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Grocery Commodities

# %%
total_revenue = []
for i in range(0, 1000):
    total_revenue.append(pulses_revenue[i] + flour_revenue[i] + rice_revenue[i] + oil_revenue[i] + soap_revenue[i])

# %%
df['Total_Revenue'] = total_revenue
df
# Out:
#      Unnamed: 0  pulses_1kg  flour_10kg  rice_5kg  oil_1ltr  soap  \
# 0             0         102         501       595       275    52
# 1             1         105         498       552       390    50
# 2             2         178         444       643       331    65
# 3             3         164         327       470       263    30
# 4             4          99         404       533       347    30
# ..          ...         ...         ...       ...       ...   ...
# 995         995          80         467       415       231    82
# 996         996         199         467       724       251    24
# 997         997         147         495       682       217    23
# 998         998         100         431       553       279    27
# 999         999         175         410       645       287    98
#
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0           3331276             13              3                1  ...
# 1           6690555              9              2                1  ...
# 2           5039662             12              4                1  ...
# 3           6230007             13              3                0  ...
# 4           1615383             13              2                1  ...
# ..              ...            ...            ...              ...  ...
# 995         1656449             13              5                1  ...
# 996         9558725             10              2                0  ...
# 997         8482745             10              6                0  ...
# 998         2608048             11              9                1  ...
# 999         9213977             13              5                1  ...
#
#      no_of_units_sold_per_day_of_flour  no_of_units_sold_per_day_of_rice  \
# 0                                   17                                11
# 1                                    5                                 9
# 2                                   18                                19
# 3                                   13                                12
# 4                                   10                                 8
# ..                                 ...                               ...
# 995                                  9                                 7
# 996                                 15                                10
# 997                                 17                                18
# 998                                 16                                16
# 999                                  8                                16
#
#      no_of_units_sold_per_day_of_oil  no_of_units_sold_per_day_of_soap  \
# 0                                  3                                26
# 1                                  8                                30
# 2                                 10                                21
# 3                                  5                                32
# 4                                  9                                15
# ..                               ...                               ...
# 995                                9                                28
# 996                               11                                16
# 997                                3                                26
# 998                                5                                21
# 999                                4                                38
#
#      profit_percentage_last_year  competition_scale  sustainability  startup  \
# 0                              1                  4               1        0
# 1                             21                  4               1        0
# 2                             34                  7               1        1
# 3                             11                  3               0        0
# 4                             32                  8               0        0
# ..                           ...                ...             ...      ...
# 995                           33                  4               1        1
# 996                           29                  5               0        0
# 997                           20                  4               0        0
# 998                           13                  4               0        0
# 999                           40                  4               0        1
#
#      management_effectivity  Total_Revenue
# 0                         0       10758375
# 1                         1        9835290
# 2                         0       11539840
# 3                         0        7759170
# 4                         0        6482400
# ..                      ...            ...
# 995                       0        9384515
# 996                       1        9299470
# 997                       0       12314370
# 998                       1        9416270
# 999                       1       10707275
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df.drop(columns = ['Unnamed: 0','pulses_1kg', 'flour_10kg', 'rice_5kg', 'oil_1ltr', 'soap', 'no_of_units_sold_per_day_of_pulses', 'no_of_units_sold_per_day_of_flour', 'no_of_units_sold_per_day_of_rice', 'no_of_units_sold_per_day_of_oil', 'no_of_units_sold_per_day_of_soap'], inplace = True)
df
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0           3331276             13              3                1
# 1           6690555              9              2                1
# 2           5039662             12              4                1
# 3           6230007             13              3                0
# 4           1615383             13              2                1
# ..              ...            ...            ...              ...
# 995         1656449             13              5                1
# 996         9558725             10              2                0
# 997         8482745             10              6                0
# 998         2608048             11              9                1
# 999         9213977             13              5                1
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            760             1549433                            1
# 1            713             1577994                           21
# 2            761             4555691                           34
# 3            637             2529141                           11
# 4            791             1700947                           32
# ..           ...                 ...                          ...
# 995          564             2257013                           33
# 996          522             3168233                           29
# 997          737             2459817                           20
# 998          807             2826335                           13
# 999          424             2605015                           40
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    4               1        0                       0
# 1                    4               1        0                       1
# 2                    7               1        1                       0
# 3                    3               0        0                       0
# 4                    8               0        0                       0
# ..                 ...             ...      ...                     ...
# 995                  4               1        1                       0
# 996                  5               0        0                       1
# 997                  4               0        0                       0
# 998                  4               0        0                       1
# 999                  4               0        1                       1
#
#      Total_Revenue
# 0         10758375
# 1          9835290
# 2         11539840
# 3          7759170
# 4          6482400
# ..             ...
# 995        9384515
# 996        9299470
# 997       12314370
# 998        9416270
# 999       10707275
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Electronics Dataset Cleaning

# %%
df1 = pd.read_csv('Electronics.csv')
df1.head()
# Out:
#    Unnamed: 0  laptop  phone  tablet  television  gaming_console  \
# 0           0  149835  60761   25032       41120           32773
# 1           1  146315   8929   33969      143484           29777
# 2           2  144420  14644   45126       98469           34560
# 3           3   73746  39407   40451       84376           36319
# 4           4   83369  54694   38094      171167           36214
#
#    amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0         5931878             12              4                0  ...
# 1         8188173             14              5                1  ...
# 2         7099039             10              9                0  ...
# 3         5599963             13              2                0  ...
# 4          883985              8              7                0  ...
#
#    no_of_units_sold_per_day_of_laptop  no_of_units_sold_per_day_of_phone  \
# 0                                   8                                  5
# 1                                   8                                  6
# 2                                   3                                  2
# 3                                   9                                  3
# 4                                   5                                  1
#
#    no_of_units_sold_per_day_of_tablet  no_of_units_sold_per_day_of_television  \
# 0                                   2                                       1
# 1                                   3                                       2
# 2                                   3                                       2
# 3                                   2                                       1
# 4                                   3                                       3
#
#    no_of_units_sold_per_day_of_gaming_console  profit_percentage_last_year  \
# 0                                           1                           23
# 1                                           2                           13
# 2                                           1                           10
# 3                                           2                           10
# 4                                           2                            3
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  6               0        0                       1
# 1                  1               0        1                       1
# 2                  7               0        1                       0
# 3                  3               0        1                       1
# 4                  7               0        0                       1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Electronics Commodities Revenue

# %%
laptop_revenue = []
for i in range(0, 1000):
    laptop_revenue.append((df1['laptop'].loc[i])*(df1['no_of_units_sold_per_day_of_laptop'].loc[i])*365)

# %%
phone_revenue = []
for i in range(0, 1000):
    phone_revenue.append((df1['phone'].loc[i])*(df1['no_of_units_sold_per_day_of_phone'].loc[i])*365)

# %%
tablet_revenue = []
for i in range(0, 1000):
    tablet_revenue.append((df1['tablet'].loc[i])*(df1['no_of_units_sold_per_day_of_tablet'].loc[i])*365)

# %%
television_revenue = []
for i in range(0, 1000):
    television_revenue.append((df1['television'].loc[i])*(df1['no_of_units_sold_per_day_of_television'].loc[i])*365)

# %%
gaming_console_revenue = []
for i in range(0, 1000):
    gaming_console_revenue.append((df1['gaming_console'].loc[i])*(df1['no_of_units_sold_per_day_of_gaming_console'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Electronics Commodities

# %%
total_revenue1 = []
for i in range(0, 1000):
    total_revenue1.append(laptop_revenue[i] + phone_revenue[i] + tablet_revenue[i] + television_revenue[i] + gaming_console_revenue[i])

# %%
df1['Total_Revenue'] = total_revenue1
df1
# Out:
#      Unnamed: 0  laptop   phone  tablet  television  gaming_console  \
# 0             0  149835   60761   25032       41120           32773
# 1             1  146315    8929   33969      143484           29777
# 2             2  144420   14644   45126       98469           34560
# 3             3   73746   39407   40451       84376           36319
# 4             4   83369   54694   38094      171167           36214
# ..          ...     ...     ...     ...         ...             ...
# 995         995  100740   88542   32477      194321           41923
# 996         996   64618   15687   43737      152133           37754
# 997         997  102388  118611   26597       53714           32074
# 998         998   87016   30348   34445      134438           26200
# 999         999  135356   69341   22388      179489           27180
#
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0           5931878             12              4                0  ...
# 1           8188173             14              5                1  ...
# 2           7099039             10              9                0  ...
# 3           5599963             13              2                0  ...
# 4            883985              8              7                0  ...
# ..              ...            ...            ...              ...  ...
# 995         9404279             10              5                0  ...
# 996         1805387              9              5                1  ...
# 997         7652611             12              2                1  ...
# 998         2473699              8              3                1  ...
# 999         7642493              6              6                0  ...
#
#      no_of_units_sold_per_day_of_phone  no_of_units_sold_per_day_of_tablet  \
# 0                                    5                                   2
# 1                                    6                                   3
# 2                                    2                                   3
# 3                                    3                                   2
# 4                                    1                                   3
# ..                                 ...                                 ...
# 995                                  1                                   1
# 996                                  3                                   2
# 997                                  5                                   3
# 998                                  4                                   3
# 999                                  6                                   4
#
#      no_of_units_sold_per_day_of_television  \
# 0                                         1
# 1                                         2
# 2                                         2
# 3                                         1
# 4                                         3
# ..                                      ...
# 995                                       2
# 996                                       1
# 997                                       1
# 998                                       1
# 999                                       1
#
#      no_of_units_sold_per_day_of_gaming_console  profit_percentage_last_year  \
# 0                                             1                           23
# 1                                             2                           13
# 2                                             1                           10
# 3                                             2                           10
# 4                                             2                            3
# ..                                          ...                          ...
# 995                                           2                           33
# 996                                           1                           48
# 997                                           1                            7
# 998                                           2                           19
# 999                                           2                           45
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    6               0        0                       1
# 1                    1               0        1                       1
# 2                    7               0        1                       0
# 3                    3               0        1                       1
# 4                    7               0        0                       1
# ..                 ...             ...      ...                     ...
# 995                  3               0        0                       1
# 996                 10               1        1                       1
# 997                  2               0        1                       0
# 998                  5               0        0                       1
# 999                  4               0        0                       0
#
#      Total_Revenue
# 0        593651330
# 1        610470895
# 2        302739760
# 3        372245615
# 4        427688750
# ..             ...
# 995      547560955
# 996      165585170
# 997      314273030
# 998      436068785
# 999      665137675
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df1.drop(columns = ['Unnamed: 0','laptop', 'phone', 'tablet', 'television', 'gaming_console', 'no_of_units_sold_per_day_of_laptop', 'no_of_units_sold_per_day_of_phone', 'no_of_units_sold_per_day_of_tablet', 'no_of_units_sold_per_day_of_television', 'no_of_units_sold_per_day_of_gaming_console'], inplace = True)
df1
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0           5931878             12              4                0
# 1           8188173             14              5                1
# 2           7099039             10              9                0
# 3           5599963             13              2                0
# 4            883985              8              7                0
# ..              ...            ...            ...              ...
# 995         9404279             10              5                0
# 996         1805387              9              5                1
# 997         7652611             12              2                1
# 998         2473699              8              3                1
# 999         7642493              6              6                0
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            870             2525987                           23
# 1            598             3523316                           13
# 2            386              494963                           10
# 3            792             3744041                           10
# 4            454             4253796                            3
# ..           ...                 ...                          ...
# 995          815             1020617                           33
# 996          694             1112166                           48
# 997          695              969584                            7
# 998          891             3906897                           19
# 999          811             4885770                           45
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    6               0        0                       1
# 1                    1               0        1                       1
# 2                    7               0        1                       0
# 3                    3               0        1                       1
# 4                    7               0        0                       1
# ..                 ...             ...      ...                     ...
# 995                  3               0        0                       1
# 996                 10               1        1                       1
# 997                  2               0        1                       0
# 998                  5               0        0                       1
# 999                  4               0        0                       0
#
#      Total_Revenue
# 0        593651330
# 1        610470895
# 2        302739760
# 3        372245615
# 4        427688750
# ..             ...
# 995      547560955
# 996      165585170
# 997      314273030
# 998      436068785
# 999      665137675
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Clothing Dataset Cleaning

# %%
df2 = pd.read_csv('Clothing.csv')
df2.head()
# Out:
#    Unnamed: 0  shirt  kurta   tops  shorts  jeans  amount_of_loan  \
# 0           0   3932   1735  18140    1191   4068         2972571
# 1           1    869   4040   4941    1787   3888          516224
# 2           2   2725   3695  19358    1099   1616         2997923
# 3           3   4992   7635  17451     916   5112         3446589
# 4           4   1125   8231  19967     776   1250         5176307
#
#    interest_rate  time_to_repay  simple_interest  ...  \
# 0             10              8                0  ...
# 1             13              7                0  ...
# 2             12              6                1  ...
# 3             13              9                0  ...
# 4              6              5                1  ...
#
#    no_of_units_sold_per_day_of_shirt  no_of_units_sold_per_day_of_kurta  \
# 0                                  3                                  6
# 1                                 10                                  9
# 2                                  7                                  3
# 3                                  3                                  1
# 4                                 12                                  2
#
#    no_of_units_sold_per_day_of_tops  no_of_units_sold_per_day_of_shorts  \
# 0                                12                                   8
# 1                                11                                   6
# 2                                 6                                   4
# 3                                10                                  13
# 4                                19                                  13
#
#    no_of_units_sold_per_day_of_jeans  profit_percentage_last_year  \
# 0                                  4                           22
# 1                                  5                            8
# 2                                  4                           21
# 3                                  6                           33
# 4                                  7                           32
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  7               1        1                       1
# 1                  9               0        0                       0
# 2                  7               0        0                       0
# 3                  8               1        1                       1
# 4                  2               1        0                       1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Clothing Commodities Revenue

# %%
shirt_revenue = []
for i in range(0, 1000):
    shirt_revenue.append((df2['shirt'].loc[i])*(df2['no_of_units_sold_per_day_of_shirt'].loc[i])*365)

# %%
kurta_revenue = []
for i in range(0, 1000):
    kurta_revenue.append((df2['kurta'].loc[i])*(df2['no_of_units_sold_per_day_of_kurta'].loc[i])*365)

# %%
tops_revenue = []
for i in range(0, 1000):
    tops_revenue.append((df2['tops'].loc[i])*(df2['no_of_units_sold_per_day_of_tops'].loc[i])*365)

# %%
shorts_revenue = []
for i in range(0, 1000):
    shorts_revenue.append((df2['shorts'].loc[i])*(df2['no_of_units_sold_per_day_of_shorts'].loc[i])*365)

# %%
jeans_revenue = []
for i in range(0, 1000):
    jeans_revenue.append((df2['jeans'].loc[i])*(df2['no_of_units_sold_per_day_of_jeans'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Clothing Commodities

# %%
total_revenue2 = []
for i in range(0, 1000):
    total_revenue2.append(shirt_revenue[i] + kurta_revenue[i] + tops_revenue[i] + shorts_revenue[i] + jeans_revenue[i])

# %%
df2['Total_Revenue'] = total_revenue2
df2
# Out:
#      Unnamed: 0  shirt  kurta   tops  shorts  jeans  amount_of_loan  \
# 0             0   3932   1735  18140    1191   4068         2972571
# 1             1    869   4040   4941    1787   3888          516224
# 2             2   2725   3695  19358    1099   1616         2997923
# 3             3   4992   7635  17451     916   5112         3446589
# 4             4   1125   8231  19967     776   1250         5176307
# ..          ...    ...    ...    ...     ...    ...             ...
# 995         995   3231   1242   6054    1469   2472         1843489
# 996         996   3042   4955  14838    1194   4303         2399765
# 997         997   2393   4879   5954     713   5334         4750608
# 998         998   4748   8678   2830     858   4067         2343216
# 999         999   1079   5866  19260    1772   3933         7885521
#
#      interest_rate  time_to_repay  simple_interest  ...  \
# 0               10              8                0  ...
# 1               13              7                0  ...
# 2               12              6                1  ...
# 3               13              9                0  ...
# 4                6              5                1  ...
# ..             ...            ...              ...  ...
# 995             10              6                1  ...
# 996              8              1                0  ...
# 997             10              1                0  ...
# 998             12              2                0  ...
# 999              8              3                1  ...
#
#      no_of_units_sold_per_day_of_kurta  no_of_units_sold_per_day_of_tops  \
# 0                                    6                                12
# 1                                    9                                11
# 2                                    3                                 6
# 3                                    1                                10
# 4                                    2                                19
# ..                                 ...                               ...
# 995                                  5                                 5
# 996                                  8                                14
# 997                                  9                                17
# 998                                  7                                17
# 999                                  6                                 5
#
#      no_of_units_sold_per_day_of_shorts  no_of_units_sold_per_day_of_jeans  \
# 0                                     8                                  4
# 1                                     6                                  5
# 2                                     4                                  4
# 3                                    13                                  6
# 4                                    13                                  7
# ..                                  ...                                ...
# 995                                   5                                  6
# 996                                   4                                  9
# 997                                   6                                 10
# 998                                   4                                  4
# 999                                  13                                  2
#
#      profit_percentage_last_year  competition_scale  sustainability  startup  \
# 0                             22                  7               1        1
# 1                              8                  9               0        0
# 2                             21                  7               0        0
# 3                             33                  8               1        1
# 4                             32                  2               1        0
# ..                           ...                ...             ...      ...
# 995                           49                 10               0        0
# 996                           14                  1               1        1
# 997                           39                  9               0        0
# 998                           45                  8               0        0
# 999                            1                  9               0        0
#
#      management_effectivity  Total_Revenue
# 0                         1       96975390
# 1                         0       47290495
# 2                         0       57366320
# 3                         1       87490865
# 4                         1      156283145
# ..                      ...            ...
# 995                       1       27306380
# 996                       0      121713995
# 997                       0       82737105
# 998                       1       52122000
# 999                       0       64395125
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df2.drop(columns = ['Unnamed: 0','shirt', 'kurta', 'tops', 'shorts', 'jeans', 'no_of_units_sold_per_day_of_shirt', 'no_of_units_sold_per_day_of_kurta', 'no_of_units_sold_per_day_of_tops', 'no_of_units_sold_per_day_of_shorts', 'no_of_units_sold_per_day_of_jeans'], inplace = True)
df2
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0           2972571             10              8                0
# 1            516224             13              7                0
# 2           2997923             12              6                1
# 3           3446589             13              9                0
# 4           5176307              6              5                1
# ..              ...            ...            ...              ...
# 995         1843489             10              6                1
# 996         2399765              8              1                0
# 997         4750608             10              1                0
# 998         2343216             12              2                0
# 999         7885521              8              3                1
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            559             4430521                           22
# 1            314              227966                            8
# 2            555             4948997                           21
# 3            732              558639                           33
# 4            789             4735759                           32
# ..           ...                 ...                          ...
# 995          634             4710066                           49
# 996          775             2806144                           14
# 997          313             2687783                           39
# 998          589             2220185                           45
# 999          313             4876833                            1
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    7               1        1                       1
# 1                    9               0        0                       0
# 2                    7               0        0                       0
# 3                    8               1        1                       1
# 4                    2               1        0                       1
# ..                 ...             ...      ...                     ...
# 995                 10               0        0                       1
# 996                  1               1        1                       0
# 997                  9               0        0                       0
# 998                  8               0        0                       1
# 999                  9               0        0                       0
#
#      Total_Revenue
# 0         96975390
# 1         47290495
# 2         57366320
# 3         87490865
# 4        156283145
# ..             ...
# 995       27306380
# 996      121713995
# 997       82737105
# 998       52122000
# 999       64395125
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Combine all datasets

# %%
newdf = pd.concat([df, df1, df2], ignore_index = True)
newdf
# Out:
#       amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0            3331276             13              3                1
# 1            6690555              9              2                1
# 2            5039662             12              4                1
# 3            6230007             13              3                0
# 4            1615383             13              2                1
# ...              ...            ...            ...              ...
# 2995         1843489             10              6                1
# 2996         2399765              8              1                0
# 2997         4750608             10              1                0
# 2998         2343216             12              2                0
# 2999         7885521              8              3                1
#
#       cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0             760             1549433                            1
# 1             713             1577994                           21
# 2             761             4555691                           34
# 3             637             2529141                           11
# 4             791             1700947                           32
# ...           ...                 ...                          ...
# 2995          634             4710066                           49
# 2996          775             2806144                           14
# 2997          313             2687783                           39
# 2998          589             2220185                           45
# 2999          313             4876833                            1
#
#       competition_scale  sustainability  startup  management_effectivity  \
# 0                     4               1        0                       0
# 1                     4               1        0                       1
# 2                     7               1        1                       0
# 3                     3               0        0                       0
# 4                     8               0        0                       0
# ...                 ...             ...      ...                     ...
# 2995                 10               0        0                       1
# 2996                  1               1        1                       0
# 2997                  9               0        0                       0
# 2998                  8               0        0                       1
# 2999                  9               0        0                       0
#
#       Total_Revenue
# 0          10758375
# 1           9835290
# 2          11539840
# 3           7759170
# 4           6482400
# ...             ...
# 2995       27306380
# 2996      121713995
# 2997       82737105
# 2998       52122000
# 2999       64395125
#
# [3000 rows x 12 columns]

# %%
newdf.to_csv('FinalDataset.csv')
